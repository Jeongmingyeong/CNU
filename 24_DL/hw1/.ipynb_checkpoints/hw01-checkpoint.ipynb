# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torch.utils.data as data_utils

import numpy as np
import matplotlib.pyplot as plt

import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.datasets import fetch_california_housing
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
wine_red = pd.read_csv("http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv", sep=';')

wine_red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
x_data = wine_red.iloc[:, :-1]
y_data = wine_red.iloc[:, -1]

print(x_data.shape)  ## 1599 개의 data 를 가지고 있는 feature 가 11개
print(y_data.shape)  ## 1599 개의 정답 data
# Out:
# (1599, 11)
# (1599,)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.2, shuffle=True)

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)

y_train
# Out:
# (1279, 11)
# (1279,)
# (320, 11)
# (320,)
# 351     6
# 141     5
# 1576    6
# 249     6
# 167     4
#        ..
# 1087    6
# 502     7
# 1509    5
# 792     6
# 161     4
# Name: quality, Length: 1279, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train) ## fit : 어떠한 분포로 맞춤 | transform : 형태를 바꿔주는 기능(?)
x_test_scaled = scaler.transform(x_test)

x_train_tensor = torch.FloatTensor(x_train_scaled)
y_train_tensor = torch.FloatTensor(y_train.to_numpy())

x_test_tensor = torch.FloatTensor(x_test_scaled)
y_test_tensor = torch.FloatTensor(y_test.to_numpy())

# %%
# 데이터 배치화 (100개 단위로 쪼갠 걸 한번 다 훑으면 1 epoch)

## dataloader 에 넣기 위해 x_train_tensor 와 y_train_tensor 를 train_data 로 변환해줌.
train_data = data_utils.TensorDataset(x_train_tensor, y_train_tensor) 

## dataloader 는 data를 batch 단위로 쪼개줌. (drop_last 는 자르고 남는 걸 버릴것이냐)
dataloader = data_utils.DataLoader(train_data, batch_size=100, shuffle=True, drop_last=True)

# 데이터 확인
for batch_idx, (x_batch, y_batch) in enumerate(dataloader):
    print(batch_idx)
    print(x_batch.shape)
    print(y_batch.shape)
    break
# Out:
# 0
# torch.Size([100, 11])
# torch.Size([100])

# %%
# parameter 정의
input_size = 11  ## 8개 feature
output_size = 1
learning_rate = 0.01
n_epochs = 100

# %%
# model 생성
model = nn.Linear(input_size, output_size)

# 손실함수 생성
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %%
# Running the model
train_loss = []
test_loss = []

for epoch in range(n_epochs+1):
    for idx, (x_batch, y_batch) in enumerate(dataloader):
        # Batch학습
        model.train() ## train모드로 바꿔줌.
        optimizer.zero_grad() ## gradiant 초기화
        y_pred = model(x_batch)
        y_pred = y_pred.reshape(-1) # y_batch 와 비교하기 위해서 차원을 맞춰줌.
        loss_train = criterion(y_pred, y_batch)
        loss_train.backward()
        optimizer.step()

        # Validation
        model.eval()
        y_test_pred = model(x_test_tensor)
        y_test_pred = y_test_pred.reshape(-1)
        loss_test = criterion(y_test_pred, y_test_tensor)

    train_loss.append(loss_train.item())
    test_loss.append(loss_test.item())
    print("epoch:{}, Loss_train:{:.2f}, Loss_test:{:.2f}".format(epoch, train_loss[-1], test_loss[-1]))
# Out:
# epoch:0, Loss_train:0.38, Loss_test:0.48
# epoch:1, Loss_train:0.41, Loss_test:0.48
# epoch:2, Loss_train:0.52, Loss_test:0.48
# epoch:3, Loss_train:0.34, Loss_test:0.48
# epoch:4, Loss_train:0.33, Loss_test:0.48
# epoch:5, Loss_train:0.32, Loss_test:0.48
# epoch:6, Loss_train:0.35, Loss_test:0.48
# epoch:7, Loss_train:0.35, Loss_test:0.48
# epoch:8, Loss_train:0.36, Loss_test:0.48
# epoch:9, Loss_train:0.49, Loss_test:0.48
# epoch:10, Loss_train:0.41, Loss_test:0.48
# epoch:11, Loss_train:0.42, Loss_test:0.48
# epoch:12, Loss_train:0.50, Loss_test:0.48
# epoch:13, Loss_train:0.37, Loss_test:0.48
# epoch:14, Loss_train:0.33, Loss_test:0.48
# epoch:15, Loss_train:0.44, Loss_test:0.48
# epoch:16, Loss_train:0.37, Loss_test:0.48
# epoch:17, Loss_train:0.39, Loss_test:0.48
# epoch:18, Loss_train:0.49, Loss_test:0.48
# epoch:19, Loss_train:0.37, Loss_test:0.48
# epoch:20, Loss_train:0.54, Loss_test:0.48
# epoch:21, Loss_train:0.36, Loss_test:0.48
# epoch:22, Loss_train:0.37, Loss_test:0.48
# epoch:23, Loss_train:0.41, Loss_test:0.48
# epoch:24, Loss_train:0.39, Loss_test:0.48
# epoch:25, Loss_train:0.40, Loss_test:0.48
# epoch:26, Loss_train:0.33, Loss_test:0.48
# epoch:27, Loss_train:0.41, Loss_test:0.48
# epoch:28, Loss_train:0.38, Loss_test:0.48
# epoch:29, Loss_train:0.44, Loss_test:0.48
# epoch:30, Loss_train:0.50, Loss_test:0.48
# epoch:31, Loss_train:0.37, Loss_test:0.48
# epoch:32, Loss_train:0.42, Loss_test:0.48
# epoch:33, Loss_train:0.40, Loss_test:0.48
# epoch:34, Loss_train:0.41, Loss_test:0.48
# epoch:35, Loss_train:0.39, Loss_test:0.48
# epoch:36, Loss_train:0.36, Loss_test:0.48
# epoch:37, Loss_train:0.51, Loss_test:0.48
# epoch:38, Loss_train:0.46, Loss_test:0.48
# epoch:39, Loss_train:0.31, Loss_test:0.48
# epoch:40, Loss_train:0.47, Loss_test:0.48
# epoch:41, Loss_train:0.44, Loss_test:0.48
# epoch:42, Loss_train:0.51, Loss_test:0.48
# epoch:43, Loss_train:0.29, Loss_test:0.48
# epoch:44, Loss_train:0.42, Loss_test:0.48
# epoch:45, Loss_train:0.47, Loss_test:0.48
# epoch:46, Loss_train:0.28, Loss_test:0.48
# epoch:47, Loss_train:0.50, Loss_test:0.48
# epoch:48, Loss_train:0.38, Loss_test:0.48
# epoch:49, Loss_train:0.41, Loss_test:0.48
# epoch:50, Loss_train:0.43, Loss_test:0.48
# epoch:51, Loss_train:0.39, Loss_test:0.48
# epoch:52, Loss_train:0.39, Loss_test:0.48
# epoch:53, Loss_train:0.48, Loss_test:0.48
# epoch:54, Loss_train:0.29, Loss_test:0.48
# epoch:55, Loss_train:0.43, Loss_test:0.48
# epoch:56, Loss_train:0.54, Loss_test:0.48
# epoch:57, Loss_train:0.40, Loss_test:0.48
# epoch:58, Loss_train:0.39, Loss_test:0.48
# epoch:59, Loss_train:0.45, Loss_test:0.48
# epoch:60, Loss_train:0.42, Loss_test:0.48
# epoch:61, Loss_train:0.41, Loss_test:0.48
# epoch:62, Loss_train:0.31, Loss_test:0.48
# epoch:63, Loss_train:0.48, Loss_test:0.48
# epoch:64, Loss_train:0.36, Loss_test:0.48
# epoch:65, Loss_train:0.39, Loss_test:0.48
# epoch:66, Loss_train:0.38, Loss_test:0.48
# epoch:67, Loss_train:0.41, Loss_test:0.48
# epoch:68, Loss_train:0.34, Loss_test:0.48
# epoch:69, Loss_train:0.44, Loss_test:0.48
# epoch:70, Loss_train:0.49, Loss_test:0.48
# epoch:71, Loss_train:0.28, Loss_test:0.48
# epoch:72, Loss_train:0.38, Loss_test:0.48
# epoch:73, Loss_train:0.34, Loss_test:0.48
# epoch:74, Loss_train:0.43, Loss_test:0.48
# epoch:75, Loss_train:0.41, Loss_test:0.48
# epoch:76, Loss_train:0.57, Loss_test:0.48
# epoch:77, Loss_train:0.39, Loss_test:0.48
# epoch:78, Loss_train:0.42, Loss_test:0.48
# epoch:79, Loss_train:0.42, Loss_test:0.48
# epoch:80, Loss_train:0.44, Loss_test:0.48
# epoch:81, Loss_train:0.50, Loss_test:0.48
# epoch:82, Loss_train:0.32, Loss_test:0.48
# epoch:83, Loss_train:0.40, Loss_test:0.48
# epoch:84, Loss_train:0.34, Loss_test:0.48
# epoch:85, Loss_train:0.36, Loss_test:0.48
# epoch:86, Loss_train:0.40, Loss_test:0.48
# epoch:87, Loss_train:0.46, Loss_test:0.48
# epoch:88, Loss_train:0.37, Loss_test:0.48
# epoch:89, Loss_train:0.39, Loss_test:0.48
# epoch:90, Loss_train:0.50, Loss_test:0.48
# epoch:91, Loss_train:0.46, Loss_test:0.48
# epoch:92, Loss_train:0.38, Loss_test:0.48
# epoch:93, Loss_train:0.47, Loss_test:0.48
# epoch:94, Loss_train:0.45, Loss_test:0.48
# epoch:95, Loss_train:0.47, Loss_test:0.48
# epoch:96, Loss_train:0.33, Loss_test:0.48
# epoch:97, Loss_train:0.35, Loss_test:0.48
# epoch:98, Loss_train:0.36, Loss_test:0.48
# epoch:99, Loss_train:0.29, Loss_test:0.48
# epoch:100, Loss_train:0.46, Loss_test:0.48

# %%
plt.figure()
plt.plot(train_loss, label='train')
plt.plot(test_loss, label='test')

plt.title('Model loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(loc='upper right')
plt.show()

# %%
# model 의 학습된 파라미터 확인
model.state_dict()
# Out:
# OrderedDict([('weight',
#               tensor([[ 0.0084, -0.1653, -0.0119,  0.0188, -0.1048,  0.0314, -0.0936, -0.0111,
#                        -0.0751,  0.1765,  0.3066]])),
#              ('bias', tensor([5.6199]))])

# %% [markdown]
# ## model
# wine의 다양한 data를 받아서 quality를 예측하는 LinearRegression model 이다.
# input data 에서 가장 뒤에 있는 quality 를 정답 y로 두고, 나머지 feature들을 x로 두어 학습시켰다.
#
# 예측의 loss 를 찍어봤을 때 train data에 대한 loss는 epoch마다 다르게 찍히지만,
# test data에 대한 loss 는 0.47정도로 일정한 것을 확인할 수 있다.
